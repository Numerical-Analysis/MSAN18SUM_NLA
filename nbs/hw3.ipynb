# %% [markdown]
# # Homework 3

# %% [markdown]
# Due 6/26 1:10 pm

# %% [markdown]
# ### 1\. We have the following slow method:

# %% [markdown]
#     def slow(xx,yy):
#         zz = np.zeros(nobs, dtype='float32')
#         for j in range(nobs):
#             x, y = xx[j], yy[j]
#             x = x*2 - y*5
#             y = x + y*2
#             z = x + y + 9
#             zz[j] = z
#         return zz

# %% [markdown]
# #### 1A. Rewrite it using **numpy** only to speed it up:
#
#       def better(xx,yy):
#
#
#
#
#
#
#
#
#
#
#
#
#           return zz

# %% [markdown]
# #### 1B. Rewrite it using **numba** to make it even faster:

# %% [markdown]
#     @
#     def best(xx,yy):
#
#
#
#
#
#
#
#
#
#
#
#
#         return zz

# %% [markdown]
# ### 2\. Solving $Ax=y$ using Gaussian elimination.
#
# $A$ is $n\times n$
#
# What is the Big O for a general matrix $A$?
#
# What is the Big O if $A$ is upper triangula? Justify your answer.

# %% [markdown]
# ### 3\. Let $A=QR$ be the reduced QR decomposition of $A$, are diag(R) the singular values of $A$? Why?

# %% [markdown]
# ### 4\. For each statement, choose all of the options that make it true (can be none, one, or several answers):

# %% [markdown]
# #### 4a Numpy:
#
# a. automatically vectorizes operations
#
# b. uses SIMD
#
# c. automatically parallelizes operations

# %% [markdown]
# #### 4b The least squares linear regression can be calculated using:
#
# a. QR decomposition
#
# b. Cholesky decomposition
#
# c. Robust PCA
#
# d. SVD

# %% [markdown]
# ### 5 Below is Phase I of the engenvalue algorithm for a 5 by 5 matrix:
#
# $\left[\begin{array}{ccccc}
# *&*&*&*&*\\
# \times&*&*&*&*\\
# \times&*&*&*&*\\
# \times&*&*&*&*\\
# \times&*&*&*&*
# \end{array}\right]$  $\rightarrow$  $\left[\begin{array}{ccccc}
# *&*&*&*&*\\
# *&*&*&*&*\\
# &\times&*&*&*\\
# &\times&*&*&*\\
# &\times&*&*&*
# \end{array}\right]$  $\rightarrow$  $\left[\begin{array}{ccccc}
# *&*&*&*&*\\
# *&*&*&*&*\\
# &*&*&*&*\\
# &&\times&*&*\\
# &&\times&*&*
# \end{array}\right]$  $\rightarrow$  $\left[\begin{array}{ccccc}
# *&*&*&*&*\\
# *&*&*&*&*\\
# &*&*&*&*\\
# &&*&*&*\\
# &&&*&*
# \end{array}\right]$
#
# $\hspace{1.5cm}$ $A_0=A $ $\hspace{1.8cm}$ $A_1=Q_1A_0Q_1^T$ $\hspace{1.8cm}$ $A_2=Q_2A_1Q_2^T$ $\hspace{1.5cm}$ $B=Q_3A_2Q_3^T$
#
# We talked about how to find $Q_1$ in class, describe how to find $Q_2$.

# %% [markdown]
# ### 6\. Verify that $A^{(k)}=[Q^{(k)}]^TA^{(k-1)}Q^{(k)}$ in the shifted QR algorithm.
